# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import numpy as np # Import numpy to create dummy data

# Example dataset
# Define X and y with your actual data loading logic
# For demonstration, creating dummy data:
X = np.random.rand(100, 10) # 100 samples, 10 features
y = np.random.rand(100, 1)  # 100 samples, 1 target variable

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Normalize input
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Build the model
model = Sequential([
    Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
    Dense(32, activation='relu'),
    Dense(1)  # Linear activation for regression
])

model.compile(optimizer='adam', loss='mse', metrics=['mae'])

# Train the model
model.fit(X_train, y_train, epochs=100, validation_split=0.2)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 213ms/step - loss: 1.1846 - mae: 0.9600 - val_loss: 1.0908 - val_mae: 0.9443
# Epoch 2/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.8847 - mae: 0.8227 - val_loss: 0.8352 - val_mae: 0.8037
# Epoch 3/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.6710 - mae: 0.7034 - val_loss: 0.6313 - val_mae: 0.6720
# Epoch 4/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.5579 - mae: 0.6306 - val_loss: 0.4726 - val_mae: 0.5550
# Epoch 5/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.3816 - mae: 0.4999 - val_loss: 0.3603 - val_mae: 0.4641
# Epoch 6/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.3155 - mae: 0.4437 - val_loss: 0.2791 - val_mae: 0.3875
# Epoch 7/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.2460 - mae: 0.3861 - val_loss: 0.2210 - val_mae: 0.3539
# Epoch 8/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.2239 - mae: 0.3646 - val_loss: 0.1826 - val_mae: 0.3333
# Epoch 9/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.2008 - mae: 0.3409 - val_loss: 0.1571 - val_mae: 0.3215
# Epoch 10/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.1700 - mae: 0.3218 - val_loss: 0.1398 - val_mae: 0.3110
# Epoch 11/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.1640 - mae: 0.3281 - val_loss: 0.1281 - val_mae: 0.3031
# Epoch 12/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.1321 - mae: 0.2937 - val_loss: 0.1210 - val_mae: 0.2974
# Epoch 13/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.1317 - mae: 0.2887 - val_loss: 0.1180 - val_mae: 0.2938
# Epoch 14/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.1092 - mae: 0.2657 - val_loss: 0.1180 - val_mae: 0.2912
# Epoch 15/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0925 - mae: 0.2415 - val_loss: 0.1200 - val_mae: 0.2893
# Epoch 16/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0788 - mae: 0.2253 - val_loss: 0.1242 - val_mae: 0.2880
# Epoch 17/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0836 - mae: 0.2337 - val_loss: 0.1287 - val_mae: 0.2889
# Epoch 18/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0714 - mae: 0.2157 - val_loss: 0.1327 - val_mae: 0.2924
# Epoch 19/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0687 - mae: 0.2149 - val_loss: 0.1350 - val_mae: 0.2956
# Epoch 20/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0630 - mae: 0.2032 - val_loss: 0.1360 - val_mae: 0.2969
# Epoch 21/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0641 - mae: 0.2081 - val_loss: 0.1352 - val_mae: 0.2957
# Epoch 22/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0576 - mae: 0.1942 - val_loss: 0.1319 - val_mae: 0.2915
# Epoch 23/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0530 - mae: 0.1856 - val_loss: 0.1274 - val_mae: 0.2853
# Epoch 24/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0532 - mae: 0.1865 - val_loss: 0.1218 - val_mae: 0.2792
# Epoch 25/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0462 - mae: 0.1766 - val_loss: 0.1160 - val_mae: 0.2723
# Epoch 26/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0465 - mae: 0.1790 - val_loss: 0.1106 - val_mae: 0.2656
# Epoch 27/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0411 - mae: 0.1662 - val_loss: 0.1056 - val_mae: 0.2590
# Epoch 28/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0440 - mae: 0.1685 - val_loss: 0.1012 - val_mae: 0.2529
# Epoch 29/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0399 - mae: 0.1641 - val_loss: 0.0980 - val_mae: 0.2484
# Epoch 30/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0428 - mae: 0.1662 - val_loss: 0.0955 - val_mae: 0.2447
# Epoch 31/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0372 - mae: 0.1532 - val_loss: 0.0934 - val_mae: 0.2414
# Epoch 32/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0359 - mae: 0.1508 - val_loss: 0.0921 - val_mae: 0.2393
# Epoch 33/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0318 - mae: 0.1462 - val_loss: 0.0918 - val_mae: 0.2387
# Epoch 34/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0297 - mae: 0.1402 - val_loss: 0.0919 - val_mae: 0.2386
# Epoch 35/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0289 - mae: 0.1390 - val_loss: 0.0919 - val_mae: 0.2385
# Epoch 36/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0319 - mae: 0.1409 - val_loss: 0.0919 - val_mae: 0.2380
# Epoch 37/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0269 - mae: 0.1336 - val_loss: 0.0922 - val_mae: 0.2380
# Epoch 38/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0277 - mae: 0.1299 - val_loss: 0.0923 - val_mae: 0.2373
# Epoch 39/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0249 - mae: 0.1279 - val_loss: 0.0922 - val_mae: 0.2364
# Epoch 40/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0231 - mae: 0.1225 - val_loss: 0.0919 - val_mae: 0.2353
# Epoch 41/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0219 - mae: 0.1182 - val_loss: 0.0914 - val_mae: 0.2342
# Epoch 42/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0244 - mae: 0.1230 - val_loss: 0.0909 - val_mae: 0.2329
# Epoch 43/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0241 - mae: 0.1210 - val_loss: 0.0903 - val_mae: 0.2314
# Epoch 44/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0187 - mae: 0.1082 - val_loss: 0.0897 - val_mae: 0.2297
# Epoch 45/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0213 - mae: 0.1123 - val_loss: 0.0891 - val_mae: 0.2281
# Epoch 46/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0176 - mae: 0.1048 - val_loss: 0.0884 - val_mae: 0.2265
# Epoch 47/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0199 - mae: 0.1092 - val_loss: 0.0878 - val_mae: 0.2251
# Epoch 48/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0164 - mae: 0.1017 - val_loss: 0.0875 - val_mae: 0.2239
# Epoch 49/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0183 - mae: 0.1051 - val_loss: 0.0873 - val_mae: 0.2230
# Epoch 50/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0166 - mae: 0.0971 - val_loss: 0.0871 - val_mae: 0.2222
# Epoch 51/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0168 - mae: 0.0980 - val_loss: 0.0870 - val_mae: 0.2216
# Epoch 52/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0155 - mae: 0.0940 - val_loss: 0.0872 - val_mae: 0.2217
# Epoch 53/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0169 - mae: 0.1004 - val_loss: 0.0872 - val_mae: 0.2219
# Epoch 54/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0135 - mae: 0.0929 - val_loss: 0.0871 - val_mae: 0.2220
# Epoch 55/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0125 - mae: 0.0869 - val_loss: 0.0868 - val_mae: 0.2220
# Epoch 56/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0119 - mae: 0.0849 - val_loss: 0.0867 - val_mae: 0.2219
# Epoch 57/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0109 - mae: 0.0809 - val_loss: 0.0865 - val_mae: 0.2219
# Epoch 58/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0131 - mae: 0.0871 - val_loss: 0.0863 - val_mae: 0.2219
# Epoch 59/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0126 - mae: 0.0836 - val_loss: 0.0861 - val_mae: 0.2217
# Epoch 60/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0101 - mae: 0.0780 - val_loss: 0.0858 - val_mae: 0.2220
# Epoch 61/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0101 - mae: 0.0780 - val_loss: 0.0857 - val_mae: 0.2224
# Epoch 62/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0095 - mae: 0.0750 - val_loss: 0.0856 - val_mae: 0.2228
# Epoch 63/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0107 - mae: 0.0756 - val_loss: 0.0855 - val_mae: 0.2233
# Epoch 64/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0109 - mae: 0.0789 - val_loss: 0.0854 - val_mae: 0.2236
# Epoch 65/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0101 - mae: 0.0731 - val_loss: 0.0853 - val_mae: 0.2241
# Epoch 66/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0103 - mae: 0.0751 - val_loss: 0.0854 - val_mae: 0.2246
# Epoch 67/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0096 - mae: 0.0718 - val_loss: 0.0855 - val_mae: 0.2250
# Epoch 68/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0077 - mae: 0.0669 - val_loss: 0.0854 - val_mae: 0.2254
# Epoch 69/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0097 - mae: 0.0733 - val_loss: 0.0853 - val_mae: 0.2258
# Epoch 70/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0086 - mae: 0.0664 - val_loss: 0.0853 - val_mae: 0.2262
# Epoch 71/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0069 - mae: 0.0622 - val_loss: 0.0854 - val_mae: 0.2266
# Epoch 72/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0073 - mae: 0.0657 - val_loss: 0.0854 - val_mae: 0.2271
# Epoch 73/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0082 - mae: 0.0648 - val_loss: 0.0853 - val_mae: 0.2275
# Epoch 74/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0065 - mae: 0.0608 - val_loss: 0.0854 - val_mae: 0.2280
# Epoch 75/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0077 - mae: 0.0632 - val_loss: 0.0854 - val_mae: 0.2285
# Epoch 76/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0057 - mae: 0.0565 - val_loss: 0.0854 - val_mae: 0.2289
# Epoch 77/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0073 - mae: 0.0612 - val_loss: 0.0854 - val_mae: 0.2292
# Epoch 78/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0053 - mae: 0.0540 - val_loss: 0.0855 - val_mae: 0.2296
# Epoch 79/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0064 - mae: 0.0555 - val_loss: 0.0856 - val_mae: 0.2301
# Epoch 80/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0049 - mae: 0.0511 - val_loss: 0.0858 - val_mae: 0.2304
# Epoch 81/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0048 - mae: 0.0503 - val_loss: 0.0859 - val_mae: 0.2307
# Epoch 82/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0059 - mae: 0.0537 - val_loss: 0.0858 - val_mae: 0.2311
# Epoch 83/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0058 - mae: 0.0522 - val_loss: 0.0857 - val_mae: 0.2313
# Epoch 84/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0053 - mae: 0.0491 - val_loss: 0.0857 - val_mae: 0.2316
# Epoch 85/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0056 - mae: 0.0517 - val_loss: 0.0858 - val_mae: 0.2320
# Epoch 86/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0041 - mae: 0.0464 - val_loss: 0.0860 - val_mae: 0.2323
# Epoch 87/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0050 - mae: 0.0481 - val_loss: 0.0861 - val_mae: 0.2326
# Epoch 88/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0050 - mae: 0.0470 - val_loss: 0.0862 - val_mae: 0.2329
# Epoch 89/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0046 - mae: 0.0458 - val_loss: 0.0864 - val_mae: 0.2333
# Epoch 90/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0046 - mae: 0.0451 - val_loss: 0.0865 - val_mae: 0.2336
# Epoch 91/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0046 - mae: 0.0457 - val_loss: 0.0866 - val_mae: 0.2339
# Epoch 92/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0045 - mae: 0.0450 - val_loss: 0.0867 - val_mae: 0.2343
# Epoch 93/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0030 - mae: 0.0382 - val_loss: 0.0868 - val_mae: 0.2346
# Epoch 94/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0034 - mae: 0.0418 - val_loss: 0.0869 - val_mae: 0.2349
# Epoch 95/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0031 - mae: 0.0394 - val_loss: 0.0871 - val_mae: 0.2352
# Epoch 96/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0029 - mae: 0.0379 - val_loss: 0.0873 - val_mae: 0.2355
# Epoch 97/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0027 - mae: 0.0363 - val_loss: 0.0873 - val_mae: 0.2357
# Epoch 98/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0028 - mae: 0.0365 - val_loss: 0.0874 - val_mae: 0.2360
# Epoch 99/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0037 - mae: 0.0391 - val_loss: 0.0874 - val_mae: 0.2362
# Epoch 100/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0035 - mae: 0.0379 - val_loss: 0.0874 - val_mae: 0.2364

# %% [markdown]
# Here’s a concise and informative blog post on how **Artificial Neural Networks (ANNs)** are used in **regression problems**:
#
# ---
#
# # Using Artificial Neural Networks (ANN) for Regression Problems
#
# Artificial Neural Networks (ANNs) are widely known for classification tasks, but they are also powerful tools for **regression problems**—where the goal is to predict **continuous** values rather than discrete categories.
#
# ### What Is Regression?
#
# Regression involves modeling the relationship between a **dependent variable** (output) and one or more **independent variables** (inputs). Unlike classification, regression predicts quantities such as price, temperature, or demand.
#
# ### Why Use ANN for Regression?
#
# Traditional regression techniques (like linear or polynomial regression) can struggle with:
#
# * **Nonlinear relationships**
# * **High-dimensional data**
# * **Complex feature interactions**
#
# ANNs handle these scenarios well because of their ability to **learn complex, nonlinear mappings** from input to output.
#
# ---
#
# ### ANN Architecture for Regression
#
# A typical ANN used for regression includes:
#
# * **Input Layer**: Takes the input features.
# * **Hidden Layers**: One or more layers with activation functions (like ReLU).
# * **Output Layer**: A single neuron (for scalar output) with **no activation function** or a **linear activation**, depending on the problem.
#
# #### Example:
#
# ```plaintext
# Input → Dense (ReLU) → Dense (ReLU) → Dense (Linear) → Output
# ```
#
# ---
#
# ### Key Components
#
# * **Loss Function**: Use regression-specific loss functions like **Mean Squared Error (MSE)** or **Mean Absolute Error (MAE)**.
# * **Optimizer**: Common choices include **Adam** or **SGD**.
# * **Evaluation Metrics**: R² score, MSE, RMSE, or MAE.
#
# ---
#
# ### Implementation Example (Python with Keras)
#
# ```python
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import Dense
# from sklearn.preprocessing import StandardScaler
# from sklearn.model_selection import train_test_split
#
# # Example dataset
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
#
# # Normalize input
# scaler = StandardScaler()
# X_train = scaler.fit_transform(X_train)
# X_test = scaler.transform(X_test)
#
# # Build the model
# model = Sequential([
#     Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
#     Dense(32, activation='relu'),
#     Dense(1)  # Linear activation for regression
# ])
#
# model.compile(optimizer='adam', loss='mse', metrics=['mae'])
#
# # Train the model
# model.fit(X_train, y_train, epochs=100, validation_split=0.2)
# ```
#
# ---
#
# ### Tips for Better Performance
#
# * **Normalize inputs** to speed up learning.
# * **Tune architecture** (number of layers, neurons).
# * Use **early stopping** to prevent overfitting.
# * Perform **cross-validation** for reliable evaluation.
#
# ---
#
# ### Conclusion
#
# ANNs provide a flexible and powerful approach to regression tasks, especially when the underlying data relationships are nonlinear or complex. With proper architecture and training, they can outperform traditional methods on a wide variety of real-world regression problems.
#
# ---
